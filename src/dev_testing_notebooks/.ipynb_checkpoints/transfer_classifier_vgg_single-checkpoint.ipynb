# %%
import os
import torch
import torchvision

import h5py
import deepdish as dd

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision

import matplotlib.pyplot as plt

from PIL import Image

import time
import pickle as pkl

# %%
n_epochs = 100
batch_size_train = 4# was 64
batch_size_test = 4
learning_rate = 0.001
momentum = 0.1
log_interval = 31
tt_factor = 0.8
orientation = 'AP'
num_imgs = 4000

random_seed = 1
#torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
''' 
    NOTES: 
    - it's "No Finding" not "No findings"
    - it's "Pleural_Thickening" not "Pleural_thickening"
    - it's not "Nodule Mass", but rather "Nodule" and "Mass" separately
'''
disease_map = {"Atelectasis" : 0, "Consolidation" : 1, "Infiltration" : 2, "Pneumothorax": 3, "Edema": 4,
               "Emphysema": 5, "Fibrosis": 6, "Effusion" : 7, "Pneumonia" : 8, "Pleural_Thickening" : 9,
               "Cardiomegaly" : 10, "Nodule" : 11, "Mass" : 12, "Hernia" : 13, "No Finding" : 14 }

# %%
class GetLoader(torch.utils.data.Dataset):
    '''
        Params: data - the data dictionary
                view - the orientation you want to look at
                diseases - the diseases you would like to look at
                num_imgs - the number of images of each disease you would like
                factor - the ratio of training and testing data
                typ - 0 for training, 1 for testing
    '''
    def __init__(self, data, view, diseases, num_imgs, factor, typ, transforms=None):
        
        #private data
        self.root = os.path.join('data/sorted_images',)
        self.data = data # dict object
        self.transforms = transforms
        self.len_data = 0
        datalist = []
        
        #Creating the datalist
        for i in range(len(diseases)):
            if len(data[view][diseases[i]]) <= num_imgs: #if the folder has less images than the desired number of images
                if typ == 0:
                    start = 0
                    end = int(len(data[view][diseases[i]])*factor)
                else:
                    start = int(len(data[view][diseases[i]])*factor)
                    end = -1
            else:
                if typ == 0:
                    start = 0
                    end = int(num_imgs*factor)
                else:
                    start = int(num_imgs*factor)
                    end = num_imgs
            datalist.append(self.data[view][diseases[i]][start:end])
        
        for item in datalist:
            self.len_data += len(item)
        
        
        self.img_paths = []
        self.img_labels = []
        
        for dis in datalist:
            for data in dis:
                #creating the image path
                data['img_path'] = os.path.join(self.root, data['classes'][0], view, data['img_name'])            
                diseases = data['classes']
                
                # TODO: we want the 1-hot vector for full-class net, not for 1 class net
                # what is below is very much hardcoded
                if data['classes'][0] != "No Finding":
                    label = 1
                else:
                    label = 0
                
                label = torch.Tensor([label])

#                 one_hot = [0] * 15
#                 hot_index = disease_map[data['classes'][0]]
#                 one_hot[hot_index] = 1
#                 data['label_tensor'] = torch.Tensor(one_hot)
                
                #modifying the attributes
                self.img_paths.append(data['img_path'])
                self.img_labels.append(label)
                # self.img_labels.append(data['label_tensor'])
            

    def __getitem__(self, item):
        
        img_path, img_label = self.img_paths[item], self.img_labels[item]
  
        # TODO: fix this hot fix -> recreate data object with underscore in name
        img_path = img_path.replace('No Finding', 'No_Finding')
        try:
            img = Image.open(img_path).convert('RGB')
        except:
            img_path = img_path.replace('/AP/', '/PA/')
            img = Image.open(img_path).convert('RGB')
        self.cur_img_path = img_path

        if self.transforms is not None:
            for t in self.transforms:
                img = t(img)

        return img, img_label
    
    def get_img_path(self):
        return self.cur_img_path

    def __len__(self):
        return self.len_data

# %% [markdown]
# ### load in datasets

# %%
pkl_load = open('dataset.pickle', 'rb')
data = pkl.load(pkl_load)
pkl_load.close()
print("data loaded in successfully")
# Out:
# data loaded in successfully

# %%
print(data['AP'].keys())
# Out:
# dict_keys(['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia', 'No Finding'])

# %%
transforms = [torchvision.transforms.ToTensor()] # no longer grayscale conversion
#0 = train, 1 = test
dataset_train = GetLoader(data, orientation, ['Nodule', 'No Finding'],
                          num_imgs, tt_factor, 0, transforms)
dataset_test = GetLoader(data, orientation, ['Nodule', 'No Finding'],
                          num_imgs, tt_factor, 1, transforms)
print(len(dataset_train))
print(len(dataset_test))
# Out:
# 4923
# 1230

# %%
train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size_train, shuffle=True, num_workers=1)
test_loader = torch.utils.data.DataLoader(dataset_test, batch_size=batch_size_train, shuffle=True, num_workers=1)

print(len(train_loader))
print(len(test_loader))
# Out:
# 1231
# 308

# %%
model = torch.hub.load('pytorch/vision:v0.6.0', 'vgg11', pretrained=True)
# Out:
# Using cache found in /home/npp002/.cache/torch/hub/pytorch_vision_v0.6.0

# %%
model.classifier[6] = nn.Sequential(*[
    nn.Linear(in_features=4096, out_features=500, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=500, out_features=1, bias=True),
    nn.Sigmoid()
])

# %%
layers = [0, 3, 6, 8, 11, 13, 16, 18]
outs_per_layer = [64, 128, 256, 256, 512, 512, 512, 512]
for i, out_f in zip(layers, outs_per_layer):
    model.features[i] = nn.Sequential(*[model.features[i], nn.BatchNorm2d(out_f)])

# %%
model.children
# Out:
# <bound method Module.children of VGG(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ReLU(inplace=True)
#     (8): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12): ReLU(inplace=True)
#     (13): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (17): ReLU(inplace=True)
#     (18): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=500, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=500, out_features=1, bias=True)
#       (4): Sigmoid()
#     )
#   )
# )>

# %%
network = model
#network = torchvision.models.vgg11(pretrained=False)
#network.fc = nn.Linear(512, 15)
network = torch.nn.DataParallel(network)
network.cuda()
optimizer = optim.SGD(network.parameters(), lr=learning_rate,
                      momentum=momentum)
print('Trainable params: {}'.format(sum(p.numel() for p in network.parameters() if p.requires_grad)))
# Out:
# Trainable params: 130820841

# %%
## source: https://gist.github.com/the-bass/cae9f3976866776dea17a5049013258d
def hard_binary_accuracy(batch, labels):
    batch = torch.round(batch)
    confusion_matrix = batch / labels
    
    """ Returns the confusion matrix for the values in the `prediction` and `truth`
    tensors, i.e. the amount of positions where the values of `prediction`
    and `truth` are
    - 1 and 1 (True Positive)
    - 1 and 0 (False Positive)
    - 0 and 0 (True Negative)
    - 0 and 1 (False Negative)
    """

    confusion_matrix = batch / labels
    # Element-wise division of the 2 tensors returns a new tensor which holds a
    # unique value for each case:
    #   1     where prediction and truth are 1 (True Positive)
    #   inf   where prediction is 1 and truth is 0 (False Positive)
    #   nan   where prediction and truth are 0 (True Negative)
    #   0     where prediction is 0 and truth is 1 (False Negative)

    true_positives = torch.sum(confusion_matrix == 1).item()
    false_positives = torch.sum(confusion_matrix == float('inf')).item()
    true_negatives = torch.sum(torch.isnan(confusion_matrix)).item()
    false_negatives = torch.sum(confusion_matrix == 0).item()

    return true_positives, false_positives, true_negatives, false_negatives

# %%
b = torch.Tensor([[[1, 1], [0, 0]], 
                  [[1, 1], [0, 0]]])

l = torch.Tensor([[[1, 1], [0, 0]], 
                  [[1, 1], [0, 0]]])
hard_binary_accuracy(b, l)
# Out:
# (4, 0, 4, 0)

# %%
def max_pred_conversion(batch, label):
    pass

# %%
def train(epoch):

    network.train()
    train_losses = []
    num_tested = 0
    net_loss = 0
    
    total_true_pos, total_false_pos, total_true_neg, total_false_neg = 0, 0, 0, 0
    
    for batch_idx, (data, target) in enumerate(train_loader):  # (output - actual )
        
        if torch.cuda.is_available:
            data, target = data.cuda(), target.cuda()

        output = network(data)
        
        criterion = torch.nn.BCELoss()  # 1 0 1 0 0 0 
        loss = criterion(output, target)
        loss.backward()
        
        net_loss += loss.detach().cpu().item()
        train_losses.append(loss.item())

        num_tested += len(data)
        
        #if True or batch_idx == len(train_loader) - 1:
        optimizer.step()
        optimizer.zero_grad()

        pred = output.detach().clone().cpu()
        target = target.cpu()

        true_pos, false_pos, true_neg, false_neg = hard_binary_accuracy(pred, target)
        total_true_pos += true_pos
        total_false_pos += false_pos
        total_true_neg += true_neg
        total_false_neg += false_neg
            
        
    net_loss /= len(train_loader)
    return net_loss, total_true_pos, total_false_pos, total_true_neg, total_false_neg

# %%
def test():
    
    network.eval()
    test_losses = []
    net_loss = 0    

    total_true_pos, total_false_pos, total_true_neg, total_false_neg = 0, 0, 0, 0

    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            if torch.cuda.is_available:
                data, target = data.cuda(), target.cuda()
            
            output = network(data)
            criterion = torch.nn.BCELoss()
            net_loss += criterion(output, target).item()

            pred = output.detach().clone().cpu()
            target = target.cpu()
            
            true_pos, false_pos, true_neg, false_neg = hard_binary_accuracy(pred, target)
            total_true_pos += true_pos
            total_false_pos += false_pos
            total_true_neg += true_neg
            total_false_neg += false_neg
            
        
    net_loss /= len(train_loader)
    return net_loss, total_true_pos, total_false_pos, total_true_neg, total_false_neg

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
print(torch.cuda.is_available())
# Out:
# 1
# GeForce RTX 2080 Ti
# True

# %%
train_sample_size = len(train_loader) * batch_size_train
test_sample_size = len(test_loader) * batch_size_test
print(train_sample_size, test_sample_size)
# Out:
# 4924 1232

# %%
print("Starting Training...")
begin_time = time.time()

train_losses = []
test_losses = []

train_acc = []
test_acc = []

train_true_pos = []
train_false_pos = []
train_true_neg = []
train_false_neg = []

test_true_pos = []
test_false_pos = []
test_true_neg = []
test_false_neg = []



# patience_limit = 25
# patience = 0
# min_test_loss = 10

for epoch in range(1, n_epochs + 1):
    start_time = time.time()

    loss_train, true_pos_train, false_pos_train, true_neg_train, false_neg_train = train(epoch)
    loss_test, true_pos_test, false_pos_test, true_neg_test, false_neg_test = test()
    
#     print("tp / fp / tn / fn : ", true_pos_test, false_pos_test, true_neg_test, false_neg_test )
    train_losses.append(loss_train)
    test_losses.append(loss_test)
    
    n_correct_train = true_pos_train + true_neg_train
    n_correct_test = true_pos_test + true_neg_test
    
    acc_train = 100. * n_correct_train / (train_sample_size )
    acc_test = 100. * n_correct_test / (test_sample_size)
    
    train_acc.append(acc_train)
    test_acc.append(acc_test)
    
    true_pos_rate_train = 100. * true_pos_train / (train_sample_size)
    true_neg_rate_train = 100. * true_neg_train / (train_sample_size)
    false_pos_rate_train = 100. * false_pos_train / (train_sample_size)
    false_neg_rate_train = 100. * false_neg_train / (train_sample_size)
    
    true_pos_rate_test = 100. * true_pos_test / (test_sample_size)
    true_neg_rate_test = 100. * true_neg_test / (test_sample_size)
    false_pos_rate_test = 100. * false_pos_test / (test_sample_size)
    false_neg_rate_test = 100. * false_neg_test / (test_sample_size)

    train_true_pos.append(true_pos_train)
    train_false_pos.append(false_pos_train)
    train_true_neg.append(true_neg_train)
    train_false_neg.append(false_neg_train)

    test_true_pos.append(true_pos_test)
    test_false_pos.append(false_pos_test)
    test_true_neg.append(true_neg_test)
    test_false_neg.append(false_neg_test)
        
    elapsed_time = time.time() - start_time
    
    print("-----------Epoch " + str(epoch) + " (time =", round(elapsed_time, 2), "s  aka  ", round(elapsed_time / 60, 2), " mins) ----------------")
    print('Train set: Avg. loss: {:.4f},  Accuracy: {}/{} ({:.2f}%)'.format(
        loss_train, n_correct_train, train_sample_size, acc_train))
    print('''
          True Positive: {:.2f}%
          True Negative: {:.2f}%
          False Positive: {:.2f}%
          False Negative {:.2f}%
          '''.format(true_pos_rate_train, true_neg_rate_train, false_pos_rate_train, false_neg_rate_train))    
    print('\nTest set:  Avg. loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)'.format(
        loss_test, n_correct_test, test_sample_size, acc_test))
    print('''
          True Positive: {:.2f}%
          True Negative: {:.2f}%
          False Positive: {:.2f}%
          False Negative {:.2f}%
          '''.format(true_pos_rate_test, true_neg_rate_test, false_pos_rate_test, false_neg_rate_test))
    
end_time = time.time() - begin_time

print("Training complete (time =", round(end_time, 2), "s)")
# Out:
# Starting Training...
# -----------Epoch 1 (time = 469.6 s  aka   7.83  mins) ----------------
# Train set: Avg. loss: 0.6515,  Accuracy: 3181/4924 (64.60%)
#
#           True Positive: 0.28%
#           True Negative: 64.32%
#           False Positive: 0.67%
#           False Negative 34.71%
#
#
# Test set:  Avg. loss: 0.1503, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 2 (time = 471.75 s  aka   7.86  mins) ----------------
# Train set: Avg. loss: 0.6453,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1523, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 3 (time = 472.07 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6438,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1476, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 4 (time = 472.21 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6425,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1481, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 5 (time = 472.34 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6393,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1487, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 6 (time = 472.19 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6378,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1456, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 7 (time = 472.23 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6354,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1453, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 8 (time = 472.93 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.6342,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1448, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 9 (time = 473.1 s  aka   7.89  mins) ----------------
# Train set: Avg. loss: 0.6345,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1383, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 10 (time = 472.35 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6304,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1439, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 11 (time = 472.42 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6277,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1559, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 12 (time = 472.25 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6289,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1378, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 13 (time = 472.24 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6252,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1377, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 14 (time = 472.33 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6234,  Accuracy: 3200/4924 (64.99%)
#
#           True Positive: 0.00%
#           True Negative: 64.99%
#           False Positive: 0.00%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1573, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 15 (time = 472.26 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6211,  Accuracy: 3199/4924 (64.97%)
#
#           True Positive: 0.00%
#           True Negative: 64.97%
#           False Positive: 0.02%
#           False Negative 34.99%
#
#
# Test set:  Avg. loss: 0.1502, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 16 (time = 472.17 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6193,  Accuracy: 3206/4924 (65.11%)
#
#           True Positive: 0.32%
#           True Negative: 64.78%
#           False Positive: 0.20%
#           False Negative 34.67%
#
#
# Test set:  Avg. loss: 0.1389, Accuracy: 800/1232 (64.94%)
#
#           True Positive: 0.00%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.90%
#
# -----------Epoch 17 (time = 472.31 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6157,  Accuracy: 3214/4924 (65.27%)
#
#           True Positive: 0.55%
#           True Negative: 64.72%
#           False Positive: 0.26%
#           False Negative 34.44%
#
#
# Test set:  Avg. loss: 0.1402, Accuracy: 801/1232 (65.02%)
#
#           True Positive: 0.08%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.82%
#
# -----------Epoch 18 (time = 472.29 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6162,  Accuracy: 3233/4924 (65.66%)
#
#           True Positive: 1.77%
#           True Negative: 63.89%
#           False Positive: 1.10%
#           False Negative 33.23%
#
#
# Test set:  Avg. loss: 0.1318, Accuracy: 811/1232 (65.83%)
#
#           True Positive: 0.89%
#           True Negative: 64.94%
#           False Positive: 0.00%
#           False Negative 34.01%
#
# -----------Epoch 19 (time = 472.08 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6107,  Accuracy: 3248/4924 (65.96%)
#
#           True Positive: 2.29%
#           True Negative: 63.67%
#           False Positive: 1.32%
#           False Negative 32.70%
#
#
# Test set:  Avg. loss: 0.1449, Accuracy: 844/1232 (68.51%)
#
#           True Positive: 4.38%
#           True Negative: 64.12%
#           False Positive: 0.81%
#           False Negative 30.52%
#
# -----------Epoch 20 (time = 472.08 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6104,  Accuracy: 3241/4924 (65.82%)
#
#           True Positive: 2.92%
#           True Negative: 62.90%
#           False Positive: 2.09%
#           False Negative 32.07%
#
#
# Test set:  Avg. loss: 0.1328, Accuracy: 849/1232 (68.91%)
#
#           True Positive: 4.63%
#           True Negative: 64.29%
#           False Positive: 0.65%
#           False Negative 30.28%
#
# -----------Epoch 21 (time = 472.07 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6073,  Accuracy: 3265/4924 (66.31%)
#
#           True Positive: 4.59%
#           True Negative: 61.72%
#           False Positive: 3.27%
#           False Negative 30.40%
#
#
# Test set:  Avg. loss: 0.1394, Accuracy: 935/1232 (75.89%)
#
#           True Positive: 14.04%
#           True Negative: 61.85%
#           False Positive: 3.08%
#           False Negative 20.86%
#
# -----------Epoch 22 (time = 472.4 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6030,  Accuracy: 3300/4924 (67.02%)
#
#           True Positive: 6.01%
#           True Negative: 61.01%
#           False Positive: 3.98%
#           False Negative 28.98%
#
#
# Test set:  Avg. loss: 0.1344, Accuracy: 858/1232 (69.64%)
#
#           True Positive: 6.01%
#           True Negative: 63.64%
#           False Positive: 1.30%
#           False Negative 28.90%
#
# -----------Epoch 23 (time = 472.32 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.6009,  Accuracy: 3300/4924 (67.02%)
#
#           True Positive: 6.26%
#           True Negative: 60.76%
#           False Positive: 4.22%
#           False Negative 28.74%
#
#
# Test set:  Avg. loss: 0.1309, Accuracy: 862/1232 (69.97%)
#
#           True Positive: 6.01%
#           True Negative: 63.96%
#           False Positive: 0.97%
#           False Negative 28.90%
#
# -----------Epoch 24 (time = 472.02 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5948,  Accuracy: 3319/4924 (67.40%)
#
#           True Positive: 7.92%
#           True Negative: 59.48%
#           False Positive: 5.50%
#           False Negative 27.07%
#
#
# Test set:  Avg. loss: 0.1323, Accuracy: 850/1232 (68.99%)
#
#           True Positive: 5.44%
#           True Negative: 63.56%
#           False Positive: 1.38%
#           False Negative 29.46%
#
# -----------Epoch 25 (time = 472.07 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5907,  Accuracy: 3374/4924 (68.52%)
#
#           True Positive: 8.96%
#           True Negative: 59.57%
#           False Positive: 5.42%
#           False Negative 26.04%
#
#
# Test set:  Avg. loss: 0.1312, Accuracy: 988/1232 (80.19%)
#
#           True Positive: 22.56%
#           True Negative: 57.63%
#           False Positive: 7.31%
#           False Negative 12.34%
#
# -----------Epoch 26 (time = 472.15 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5905,  Accuracy: 3365/4924 (68.34%)
#
#           True Positive: 9.48%
#           True Negative: 58.85%
#           False Positive: 6.13%
#           False Negative 25.51%
#
#
# Test set:  Avg. loss: 0.1283, Accuracy: 867/1232 (70.37%)
#
#           True Positive: 6.01%
#           True Negative: 64.37%
#           False Positive: 0.57%
#           False Negative 28.90%
#
# -----------Epoch 27 (time = 472.13 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5815,  Accuracy: 3405/4924 (69.15%)
#
#           True Positive: 10.56%
#           True Negative: 58.59%
#           False Positive: 6.40%
#           False Negative 24.43%
#
#
# Test set:  Avg. loss: 0.1313, Accuracy: 927/1232 (75.24%)
#
#           True Positive: 17.69%
#           True Negative: 57.55%
#           False Positive: 7.39%
#           False Negative 17.21%
#
# -----------Epoch 28 (time = 472.0 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5844,  Accuracy: 3380/4924 (68.64%)
#
#           True Positive: 11.33%
#           True Negative: 57.31%
#           False Positive: 7.68%
#           False Negative 23.66%
#
#
# Test set:  Avg. loss: 0.1371, Accuracy: 858/1232 (69.64%)
#
#           True Positive: 5.44%
#           True Negative: 64.20%
#           False Positive: 0.73%
#           False Negative 29.46%
#
# -----------Epoch 29 (time = 472.24 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5816,  Accuracy: 3402/4924 (69.09%)
#
#           True Positive: 11.60%
#           True Negative: 57.49%
#           False Positive: 7.49%
#           False Negative 23.40%
#
#
# Test set:  Avg. loss: 0.1312, Accuracy: 908/1232 (73.70%)
#
#           True Positive: 13.15%
#           True Negative: 60.55%
#           False Positive: 4.38%
#           False Negative 21.75%
#
# -----------Epoch 30 (time = 472.3 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5721,  Accuracy: 3451/4924 (70.09%)
#
#           True Positive: 12.19%
#           True Negative: 57.90%
#           False Positive: 7.09%
#           False Negative 22.81%
#
#
# Test set:  Avg. loss: 0.1296, Accuracy: 854/1232 (69.32%)
#
#           True Positive: 5.11%
#           True Negative: 64.20%
#           False Positive: 0.73%
#           False Negative 29.79%
#
# -----------Epoch 31 (time = 472.12 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5714,  Accuracy: 3455/4924 (70.17%)
#
#           True Positive: 13.16%
#           True Negative: 57.01%
#           False Positive: 7.98%
#           False Negative 21.83%
#
#
# Test set:  Avg. loss: 0.1330, Accuracy: 932/1232 (75.65%)
#
#           True Positive: 20.70%
#           True Negative: 54.95%
#           False Positive: 9.98%
#           False Negative 14.20%
#
# -----------Epoch 32 (time = 472.15 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5687,  Accuracy: 3476/4924 (70.59%)
#
#           True Positive: 13.65%
#           True Negative: 56.95%
#           False Positive: 8.04%
#           False Negative 21.34%
#
#
# Test set:  Avg. loss: 0.1285, Accuracy: 901/1232 (73.13%)
#
#           True Positive: 14.20%
#           True Negative: 58.93%
#           False Positive: 6.01%
#           False Negative 20.70%
#
# -----------Epoch 33 (time = 472.11 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5684,  Accuracy: 3481/4924 (70.69%)
#
#           True Positive: 13.77%
#           True Negative: 56.93%
#           False Positive: 8.06%
#           False Negative 21.22%
#
#
# Test set:  Avg. loss: 0.1323, Accuracy: 942/1232 (76.46%)
#
#           True Positive: 22.32%
#           True Negative: 54.14%
#           False Positive: 10.80%
#           False Negative 12.58%
#
# -----------Epoch 34 (time = 472.15 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5657,  Accuracy: 3503/4924 (71.14%)
#
#           True Positive: 14.20%
#           True Negative: 56.95%
#           False Positive: 8.04%
#           False Negative 20.80%
#
#
# Test set:  Avg. loss: 0.1321, Accuracy: 866/1232 (70.29%)
#
#           True Positive: 9.09%
#           True Negative: 61.20%
#           False Positive: 3.73%
#           False Negative 25.81%
#
# -----------Epoch 35 (time = 472.04 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5580,  Accuracy: 3535/4924 (71.79%)
#
#           True Positive: 15.05%
#           True Negative: 56.74%
#           False Positive: 8.25%
#           False Negative 19.94%
#
#
# Test set:  Avg. loss: 0.1208, Accuracy: 919/1232 (74.59%)
#
#           True Positive: 15.34%
#           True Negative: 59.25%
#           False Positive: 5.68%
#           False Negative 19.56%
#
# -----------Epoch 36 (time = 472.06 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5536,  Accuracy: 3564/4924 (72.38%)
#
#           True Positive: 15.35%
#           True Negative: 57.03%
#           False Positive: 7.96%
#           False Negative 19.64%
#
#
# Test set:  Avg. loss: 0.1144, Accuracy: 931/1232 (75.57%)
#
#           True Positive: 13.39%
#           True Negative: 62.18%
#           False Positive: 2.76%
#           False Negative 21.51%
#
# -----------Epoch 37 (time = 472.21 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5527,  Accuracy: 3523/4924 (71.55%)
#
#           True Positive: 14.74%
#           True Negative: 56.80%
#           False Positive: 8.18%
#           False Negative 20.25%
#
#
# Test set:  Avg. loss: 0.1254, Accuracy: 889/1232 (72.16%)
#
#           True Positive: 11.04%
#           True Negative: 61.12%
#           False Positive: 3.81%
#           False Negative 23.86%
#
# -----------Epoch 38 (time = 472.13 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5467,  Accuracy: 3556/4924 (72.22%)
#
#           True Positive: 15.17%
#           True Negative: 57.05%
#           False Positive: 7.94%
#           False Negative 19.82%
#
#
# Test set:  Avg. loss: 0.1246, Accuracy: 915/1232 (74.27%)
#
#           True Positive: 15.58%
#           True Negative: 58.69%
#           False Positive: 6.25%
#           False Negative 19.32%
#
# -----------Epoch 39 (time = 472.17 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5413,  Accuracy: 3557/4924 (72.24%)
#
#           True Positive: 15.52%
#           True Negative: 56.72%
#           False Positive: 8.27%
#           False Negative 19.48%
#
#
# Test set:  Avg. loss: 0.1278, Accuracy: 906/1232 (73.54%)
#
#           True Positive: 14.61%
#           True Negative: 58.93%
#           False Positive: 6.01%
#           False Negative 20.29%
#
# -----------Epoch 40 (time = 472.16 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5420,  Accuracy: 3558/4924 (72.26%)
#
#           True Positive: 16.49%
#           True Negative: 55.77%
#           False Positive: 9.22%
#           False Negative 18.50%
#
#
# Test set:  Avg. loss: 0.1101, Accuracy: 986/1232 (80.03%)
#
#           True Positive: 22.65%
#           True Negative: 57.39%
#           False Positive: 7.55%
#           False Negative 12.26%
#
# -----------Epoch 41 (time = 472.11 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5397,  Accuracy: 3589/4924 (72.89%)
#
#           True Positive: 16.35%
#           True Negative: 56.54%
#           False Positive: 8.45%
#           False Negative 18.64%
#
#
# Test set:  Avg. loss: 0.1391, Accuracy: 857/1232 (69.56%)
#
#           True Positive: 8.69%
#           True Negative: 60.88%
#           False Positive: 4.06%
#           False Negative 26.22%
#
# -----------Epoch 42 (time = 472.08 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5333,  Accuracy: 3611/4924 (73.33%)
#
#           True Positive: 16.67%
#           True Negative: 56.66%
#           False Positive: 8.33%
#           False Negative 18.32%
#
#
# Test set:  Avg. loss: 0.1257, Accuracy: 919/1232 (74.59%)
#
#           True Positive: 17.69%
#           True Negative: 56.90%
#           False Positive: 8.04%
#           False Negative 17.21%
#
# -----------Epoch 43 (time = 471.99 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5267,  Accuracy: 3644/4924 (74.00%)
#
#           True Positive: 17.53%
#           True Negative: 56.48%
#           False Positive: 8.51%
#           False Negative 17.47%
#
#
# Test set:  Avg. loss: 0.1294, Accuracy: 909/1232 (73.78%)
#
#           True Positive: 15.99%
#           True Negative: 57.79%
#           False Positive: 7.14%
#           False Negative 18.91%
#
# -----------Epoch 44 (time = 472.19 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5232,  Accuracy: 3646/4924 (74.05%)
#
#           True Positive: 17.69%
#           True Negative: 56.36%
#           False Positive: 8.63%
#           False Negative 17.30%
#
#
# Test set:  Avg. loss: 0.1322, Accuracy: 897/1232 (72.81%)
#
#           True Positive: 15.02%
#           True Negative: 57.79%
#           False Positive: 7.14%
#           False Negative 19.89%
#
# -----------Epoch 45 (time = 472.26 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5218,  Accuracy: 3634/4924 (73.80%)
#
#           True Positive: 17.45%
#           True Negative: 56.36%
#           False Positive: 8.63%
#           False Negative 17.55%
#
#
# Test set:  Avg. loss: 0.1410, Accuracy: 870/1232 (70.62%)
#
#           True Positive: 10.55%
#           True Negative: 60.06%
#           False Positive: 4.87%
#           False Negative 24.35%
#
# -----------Epoch 46 (time = 472.01 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5183,  Accuracy: 3656/4924 (74.25%)
#
#           True Positive: 17.57%
#           True Negative: 56.68%
#           False Positive: 8.31%
#           False Negative 17.42%
#
#
# Test set:  Avg. loss: 0.1404, Accuracy: 886/1232 (71.92%)
#
#           True Positive: 22.89%
#           True Negative: 49.03%
#           False Positive: 15.91%
#           False Negative 12.01%
#
# -----------Epoch 47 (time = 471.93 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5123,  Accuracy: 3685/4924 (74.84%)
#
#           True Positive: 17.79%
#           True Negative: 57.05%
#           False Positive: 7.94%
#           False Negative 17.20%
#
#
# Test set:  Avg. loss: 0.1446, Accuracy: 855/1232 (69.40%)
#
#           True Positive: 28.65%
#           True Negative: 40.75%
#           False Positive: 24.19%
#           False Negative 6.25%
#
# -----------Epoch 48 (time = 472.68 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.5127,  Accuracy: 3673/4924 (74.59%)
#
#           True Positive: 17.59%
#           True Negative: 57.01%
#           False Positive: 7.98%
#           False Negative 17.40%
#
#
# Test set:  Avg. loss: 0.1134, Accuracy: 936/1232 (75.97%)
#
#           True Positive: 16.23%
#           True Negative: 59.74%
#           False Positive: 5.19%
#           False Negative 18.67%
#
# -----------Epoch 49 (time = 472.09 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.5054,  Accuracy: 3714/4924 (75.43%)
#
#           True Positive: 18.93%
#           True Negative: 56.50%
#           False Positive: 8.49%
#           False Negative 16.06%
#
#
# Test set:  Avg. loss: 0.1223, Accuracy: 922/1232 (74.84%)
#
#           True Positive: 14.77%
#           True Negative: 60.06%
#           False Positive: 4.87%
#           False Negative 20.13%
#
# -----------Epoch 50 (time = 472.3 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4963,  Accuracy: 3777/4924 (76.71%)
#
#           True Positive: 19.58%
#           True Negative: 57.13%
#           False Positive: 7.86%
#           False Negative 15.41%
#
#
# Test set:  Avg. loss: 0.1261, Accuracy: 937/1232 (76.06%)
#
#           True Positive: 23.86%
#           True Negative: 52.19%
#           False Positive: 12.74%
#           False Negative 11.04%
#
# -----------Epoch 51 (time = 472.24 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4945,  Accuracy: 3744/4924 (76.04%)
#
#           True Positive: 19.13%
#           True Negative: 56.90%
#           False Positive: 8.08%
#           False Negative 15.86%
#
#
# Test set:  Avg. loss: 0.1454, Accuracy: 854/1232 (69.32%)
#
#           True Positive: 13.96%
#           True Negative: 55.36%
#           False Positive: 9.58%
#           False Negative 20.94%
#
# -----------Epoch 52 (time = 472.15 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4840,  Accuracy: 3766/4924 (76.48%)
#
#           True Positive: 19.29%
#           True Negative: 57.19%
#           False Positive: 7.80%
#           False Negative 15.70%
#
#
# Test set:  Avg. loss: 0.1408, Accuracy: 887/1232 (72.00%)
#
#           True Positive: 14.69%
#           True Negative: 57.31%
#           False Positive: 7.63%
#           False Negative 20.21%
#
# -----------Epoch 53 (time = 472.05 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4853,  Accuracy: 3792/4924 (77.01%)
#
#           True Positive: 19.74%
#           True Negative: 57.27%
#           False Positive: 7.72%
#           False Negative 15.25%
#
#
# Test set:  Avg. loss: 0.1498, Accuracy: 858/1232 (69.64%)
#
#           True Positive: 23.86%
#           True Negative: 45.78%
#           False Positive: 19.16%
#           False Negative 11.04%
#
# -----------Epoch 54 (time = 471.9 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4796,  Accuracy: 3795/4924 (77.07%)
#
#           True Positive: 20.09%
#           True Negative: 56.99%
#           False Positive: 8.00%
#           False Negative 14.91%
#
#
# Test set:  Avg. loss: 0.1399, Accuracy: 878/1232 (71.27%)
#
#           True Positive: 17.86%
#           True Negative: 53.41%
#           False Positive: 11.53%
#           False Negative 17.05%
#
# -----------Epoch 55 (time = 471.98 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4727,  Accuracy: 3798/4924 (77.13%)
#
#           True Positive: 20.71%
#           True Negative: 56.42%
#           False Positive: 8.57%
#           False Negative 14.28%
#
#
# Test set:  Avg. loss: 0.1192, Accuracy: 922/1232 (74.84%)
#
#           True Positive: 13.47%
#           True Negative: 61.36%
#           False Positive: 3.57%
#           False Negative 21.43%
#
# -----------Epoch 56 (time = 472.39 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4716,  Accuracy: 3810/4924 (77.38%)
#
#           True Positive: 20.19%
#           True Negative: 57.19%
#           False Positive: 7.80%
#           False Negative 14.81%
#
#
# Test set:  Avg. loss: 0.1448, Accuracy: 860/1232 (69.81%)
#
#           True Positive: 18.59%
#           True Negative: 51.22%
#           False Positive: 13.72%
#           False Negative 16.31%
#
# -----------Epoch 57 (time = 472.1 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4647,  Accuracy: 3832/4924 (77.82%)
#
#           True Positive: 20.76%
#           True Negative: 57.07%
#           False Positive: 7.92%
#           False Negative 14.24%
#
#
# Test set:  Avg. loss: 0.1422, Accuracy: 883/1232 (71.67%)
#
#           True Positive: 18.51%
#           True Negative: 53.17%
#           False Positive: 11.77%
#           False Negative 16.40%
#
# -----------Epoch 58 (time = 472.28 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4640,  Accuracy: 3854/4924 (78.27%)
#
#           True Positive: 20.69%
#           True Negative: 57.58%
#           False Positive: 7.41%
#           False Negative 14.30%
#
#
# Test set:  Avg. loss: 0.1548, Accuracy: 844/1232 (68.51%)
#
#           True Positive: 20.29%
#           True Negative: 48.21%
#           False Positive: 16.72%
#           False Negative 14.61%
#
# -----------Epoch 59 (time = 472.09 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4607,  Accuracy: 3832/4924 (77.82%)
#
#           True Positive: 21.18%
#           True Negative: 56.64%
#           False Positive: 8.35%
#           False Negative 13.81%
#
#
# Test set:  Avg. loss: 0.1307, Accuracy: 914/1232 (74.19%)
#
#           True Positive: 17.29%
#           True Negative: 56.90%
#           False Positive: 8.04%
#           False Negative 17.61%
#
# -----------Epoch 60 (time = 472.48 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4541,  Accuracy: 3869/4924 (78.57%)
#
#           True Positive: 21.47%
#           True Negative: 57.11%
#           False Positive: 7.88%
#           False Negative 13.53%
#
#
# Test set:  Avg. loss: 0.1596, Accuracy: 816/1232 (66.23%)
#
#           True Positive: 21.59%
#           True Negative: 44.64%
#           False Positive: 20.29%
#           False Negative 13.31%
#
# -----------Epoch 61 (time = 472.28 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4554,  Accuracy: 3900/4924 (79.20%)
#
#           True Positive: 21.77%
#           True Negative: 57.43%
#           False Positive: 7.55%
#           False Negative 13.22%
#
#
# Test set:  Avg. loss: 0.1327, Accuracy: 931/1232 (75.57%)
#
#           True Positive: 14.69%
#           True Negative: 60.88%
#           False Positive: 4.06%
#           False Negative 20.21%
#
# -----------Epoch 62 (time = 472.4 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4497,  Accuracy: 3870/4924 (78.59%)
#
#           True Positive: 21.41%
#           True Negative: 57.19%
#           False Positive: 7.80%
#           False Negative 13.59%
#
#
# Test set:  Avg. loss: 0.1506, Accuracy: 848/1232 (68.83%)
#
#           True Positive: 22.16%
#           True Negative: 46.67%
#           False Positive: 18.26%
#           False Negative 12.74%
#
# -----------Epoch 63 (time = 472.2 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4415,  Accuracy: 3917/4924 (79.55%)
#
#           True Positive: 22.14%
#           True Negative: 57.41%
#           False Positive: 7.58%
#           False Negative 12.86%
#
#
# Test set:  Avg. loss: 0.1434, Accuracy: 860/1232 (69.81%)
#
#           True Positive: 19.40%
#           True Negative: 50.41%
#           False Positive: 14.53%
#           False Negative 15.50%
#
# -----------Epoch 64 (time = 472.33 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4339,  Accuracy: 3890/4924 (79.00%)
#
#           True Positive: 22.08%
#           True Negative: 56.93%
#           False Positive: 8.06%
#           False Negative 12.92%
#
#
# Test set:  Avg. loss: 0.1570, Accuracy: 836/1232 (67.86%)
#
#           True Positive: 12.82%
#           True Negative: 55.03%
#           False Positive: 9.90%
#           False Negative 22.08%
#
# -----------Epoch 65 (time = 472.4 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4246,  Accuracy: 3999/4924 (81.21%)
#
#           True Positive: 23.42%
#           True Negative: 57.80%
#           False Positive: 7.19%
#           False Negative 11.58%
#
#
# Test set:  Avg. loss: 0.1622, Accuracy: 798/1232 (64.77%)
#
#           True Positive: 23.78%
#           True Negative: 40.99%
#           False Positive: 23.94%
#           False Negative 11.12%
#
# -----------Epoch 66 (time = 472.54 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.4288,  Accuracy: 3935/4924 (79.91%)
#
#           True Positive: 22.60%
#           True Negative: 57.31%
#           False Positive: 7.68%
#           False Negative 12.39%
#
#
# Test set:  Avg. loss: 0.1198, Accuracy: 936/1232 (75.97%)
#
#           True Positive: 17.05%
#           True Negative: 58.93%
#           False Positive: 6.01%
#           False Negative 17.86%
#
# -----------Epoch 67 (time = 472.54 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.4195,  Accuracy: 3957/4924 (80.36%)
#
#           True Positive: 22.79%
#           True Negative: 57.58%
#           False Positive: 7.41%
#           False Negative 12.21%
#
#
# Test set:  Avg. loss: 0.1324, Accuracy: 917/1232 (74.43%)
#
#           True Positive: 16.15%
#           True Negative: 58.28%
#           False Positive: 6.66%
#           False Negative 18.75%
#
# -----------Epoch 68 (time = 472.34 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4154,  Accuracy: 3978/4924 (80.79%)
#
#           True Positive: 23.09%
#           True Negative: 57.70%
#           False Positive: 7.29%
#           False Negative 11.90%
#
#
# Test set:  Avg. loss: 0.1797, Accuracy: 849/1232 (68.91%)
#
#           True Positive: 7.71%
#           True Negative: 61.20%
#           False Positive: 3.73%
#           False Negative 27.19%
#
# -----------Epoch 69 (time = 472.21 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4111,  Accuracy: 3999/4924 (81.21%)
#
#           True Positive: 23.46%
#           True Negative: 57.76%
#           False Positive: 7.23%
#           False Negative 11.54%
#
#
# Test set:  Avg. loss: 0.1762, Accuracy: 770/1232 (62.50%)
#
#           True Positive: 24.35%
#           True Negative: 38.15%
#           False Positive: 26.79%
#           False Negative 10.55%
#
# -----------Epoch 70 (time = 472.6 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.4087,  Accuracy: 4012/4924 (81.48%)
#
#           True Positive: 23.54%
#           True Negative: 57.94%
#           False Positive: 7.05%
#           False Negative 11.45%
#
#
# Test set:  Avg. loss: 0.1673, Accuracy: 834/1232 (67.69%)
#
#           True Positive: 13.72%
#           True Negative: 53.98%
#           False Positive: 10.96%
#           False Negative 21.19%
#
# -----------Epoch 71 (time = 472.74 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.4008,  Accuracy: 4014/4924 (81.52%)
#
#           True Positive: 23.62%
#           True Negative: 57.90%
#           False Positive: 7.09%
#           False Negative 11.37%
#
#
# Test set:  Avg. loss: 0.1790, Accuracy: 815/1232 (66.15%)
#
#           True Positive: 11.77%
#           True Negative: 54.38%
#           False Positive: 10.55%
#           False Negative 23.13%
#
# -----------Epoch 72 (time = 472.38 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.4013,  Accuracy: 4044/4924 (82.13%)
#
#           True Positive: 23.90%
#           True Negative: 58.23%
#           False Positive: 6.76%
#           False Negative 11.09%
#
#
# Test set:  Avg. loss: 0.1844, Accuracy: 826/1232 (67.05%)
#
#           True Positive: 13.31%
#           True Negative: 53.73%
#           False Positive: 11.20%
#           False Negative 21.59%
#
# -----------Epoch 73 (time = 472.69 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3882,  Accuracy: 4052/4924 (82.29%)
#
#           True Positive: 24.03%
#           True Negative: 58.27%
#           False Positive: 6.72%
#           False Negative 10.97%
#
#
# Test set:  Avg. loss: 0.1597, Accuracy: 884/1232 (71.75%)
#
#           True Positive: 16.56%
#           True Negative: 55.19%
#           False Positive: 9.74%
#           False Negative 18.34%
#
# -----------Epoch 74 (time = 472.4 s  aka   7.87  mins) ----------------
# Train set: Avg. loss: 0.3878,  Accuracy: 4055/4924 (82.35%)
#
#           True Positive: 24.03%
#           True Negative: 58.33%
#           False Positive: 6.66%
#           False Negative 10.97%
#
#
# Test set:  Avg. loss: 0.1521, Accuracy: 878/1232 (71.27%)
#
#           True Positive: 24.84%
#           True Negative: 46.43%
#           False Positive: 18.51%
#           False Negative 10.06%
#
# -----------Epoch 75 (time = 472.59 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3749,  Accuracy: 4094/4924 (83.14%)
#
#           True Positive: 24.86%
#           True Negative: 58.29%
#           False Positive: 6.70%
#           False Negative 10.13%
#
#
# Test set:  Avg. loss: 0.1278, Accuracy: 953/1232 (77.35%)
#
#           True Positive: 21.19%
#           True Negative: 56.17%
#           False Positive: 8.77%
#           False Negative 13.72%
#
# -----------Epoch 76 (time = 472.52 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3751,  Accuracy: 4118/4924 (83.63%)
#
#           True Positive: 25.12%
#           True Negative: 58.51%
#           False Positive: 6.48%
#           False Negative 9.87%
#
#
# Test set:  Avg. loss: 0.1152, Accuracy: 999/1232 (81.09%)
#
#           True Positive: 23.05%
#           True Negative: 58.04%
#           False Positive: 6.90%
#           False Negative 11.85%
#
# -----------Epoch 77 (time = 472.66 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3766,  Accuracy: 4058/4924 (82.41%)
#
#           True Positive: 24.43%
#           True Negative: 57.98%
#           False Positive: 7.01%
#           False Negative 10.56%
#
#
# Test set:  Avg. loss: 0.1452, Accuracy: 911/1232 (73.94%)
#
#           True Positive: 18.34%
#           True Negative: 55.60%
#           False Positive: 9.33%
#           False Negative 16.56%
#
# -----------Epoch 78 (time = 472.85 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3684,  Accuracy: 4095/4924 (83.16%)
#
#           True Positive: 25.12%
#           True Negative: 58.04%
#           False Positive: 6.95%
#           False Negative 9.87%
#
#
# Test set:  Avg. loss: 0.1731, Accuracy: 861/1232 (69.89%)
#
#           True Positive: 14.29%
#           True Negative: 55.60%
#           False Positive: 9.33%
#           False Negative 20.62%
#
# -----------Epoch 79 (time = 473.09 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3599,  Accuracy: 4119/4924 (83.65%)
#
#           True Positive: 25.28%
#           True Negative: 58.37%
#           False Positive: 6.62%
#           False Negative 9.71%
#
#
# Test set:  Avg. loss: 0.1812, Accuracy: 875/1232 (71.02%)
#
#           True Positive: 10.63%
#           True Negative: 60.39%
#           False Positive: 4.55%
#           False Negative 24.27%
#
# -----------Epoch 80 (time = 472.99 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3566,  Accuracy: 4104/4924 (83.35%)
#
#           True Positive: 25.04%
#           True Negative: 58.31%
#           False Positive: 6.68%
#           False Negative 9.95%
#
#
# Test set:  Avg. loss: 0.1506, Accuracy: 924/1232 (75.00%)
#
#           True Positive: 21.75%
#           True Negative: 53.25%
#           False Positive: 11.69%
#           False Negative 13.15%
#
# -----------Epoch 81 (time = 473.34 s  aka   7.89  mins) ----------------
# Train set: Avg. loss: 0.3595,  Accuracy: 4133/4924 (83.94%)
#
#           True Positive: 25.41%
#           True Negative: 58.53%
#           False Positive: 6.46%
#           False Negative 9.59%
#
#
# Test set:  Avg. loss: 0.1929, Accuracy: 833/1232 (67.61%)
#
#           True Positive: 10.39%
#           True Negative: 57.22%
#           False Positive: 7.71%
#           False Negative 24.51%
#
# -----------Epoch 82 (time = 472.98 s  aka   7.88  mins) ----------------
# Train set: Avg. loss: 0.3464,  Accuracy: 4176/4924 (84.81%)
#
#           True Positive: 26.00%
#           True Negative: 58.81%
#           False Positive: 6.17%
#           False Negative 9.00%
#
#
# Test set:  Avg. loss: 0.1814, Accuracy: 904/1232 (73.38%)
#
#           True Positive: 12.99%
#           True Negative: 60.39%
#           False Positive: 4.55%
#           False Negative 21.92%
#
# -----------Epoch 83 (time = 473.71 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.3316,  Accuracy: 4204/4924 (85.38%)
#
#           True Positive: 26.30%
#           True Negative: 59.08%
#           False Positive: 5.91%
#           False Negative 8.69%
#
#
# Test set:  Avg. loss: 0.2034, Accuracy: 802/1232 (65.10%)
#
#           True Positive: 20.29%
#           True Negative: 44.81%
#           False Positive: 20.13%
#           False Negative 14.61%
#
# -----------Epoch 84 (time = 473.7 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.3312,  Accuracy: 4188/4924 (85.05%)
#
#           True Positive: 26.20%
#           True Negative: 58.85%
#           False Positive: 6.13%
#           False Negative 8.79%
#
#
# Test set:  Avg. loss: 0.1391, Accuracy: 934/1232 (75.81%)
#
#           True Positive: 21.19%
#           True Negative: 54.63%
#           False Positive: 10.31%
#           False Negative 13.72%
#
# -----------Epoch 85 (time = 473.7 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.3142,  Accuracy: 4272/4924 (86.76%)
#
#           True Positive: 27.21%
#           True Negative: 59.55%
#           False Positive: 5.44%
#           False Negative 7.78%
#
#
# Test set:  Avg. loss: 0.2123, Accuracy: 845/1232 (68.59%)
#
#           True Positive: 13.07%
#           True Negative: 55.52%
#           False Positive: 9.42%
#           False Negative 21.83%
#
# -----------Epoch 86 (time = 473.82 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.3214,  Accuracy: 4246/4924 (86.23%)
#
#           True Positive: 26.81%
#           True Negative: 59.42%
#           False Positive: 5.56%
#           False Negative 8.18%
#
#
# Test set:  Avg. loss: 0.1842, Accuracy: 883/1232 (71.67%)
#
#           True Positive: 16.15%
#           True Negative: 55.52%
#           False Positive: 9.42%
#           False Negative 18.75%
#
# -----------Epoch 87 (time = 474.26 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.3163,  Accuracy: 4258/4924 (86.47%)
#
#           True Positive: 26.79%
#           True Negative: 59.69%
#           False Positive: 5.30%
#           False Negative 8.20%
#
#
# Test set:  Avg. loss: 0.1480, Accuracy: 920/1232 (74.68%)
#
#           True Positive: 17.13%
#           True Negative: 57.55%
#           False Positive: 7.39%
#           False Negative 17.78%
#
# -----------Epoch 88 (time = 474.44 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.3081,  Accuracy: 4261/4924 (86.54%)
#
#           True Positive: 27.23%
#           True Negative: 59.30%
#           False Positive: 5.69%
#           False Negative 7.76%
#
#
# Test set:  Avg. loss: 0.1805, Accuracy: 854/1232 (69.32%)
#
#           True Positive: 20.29%
#           True Negative: 49.03%
#           False Positive: 15.91%
#           False Negative 14.61%
#
# -----------Epoch 89 (time = 475.02 s  aka   7.92  mins) ----------------
# Train set: Avg. loss: 0.3037,  Accuracy: 4258/4924 (86.47%)
#
#           True Positive: 27.32%
#           True Negative: 59.16%
#           False Positive: 5.83%
#           False Negative 7.68%
#
#
# Test set:  Avg. loss: 0.1771, Accuracy: 914/1232 (74.19%)
#
#           True Positive: 19.81%
#           True Negative: 54.38%
#           False Positive: 10.55%
#           False Negative 15.10%
#
# -----------Epoch 90 (time = 475.15 s  aka   7.92  mins) ----------------
# Train set: Avg. loss: 0.2904,  Accuracy: 4335/4924 (88.04%)
#
#           True Positive: 27.84%
#           True Negative: 60.19%
#           False Positive: 4.79%
#           False Negative 7.15%
#
#
# Test set:  Avg. loss: 0.1658, Accuracy: 899/1232 (72.97%)
#
#           True Positive: 17.13%
#           True Negative: 55.84%
#           False Positive: 9.09%
#           False Negative 17.78%
#
# -----------Epoch 91 (time = 474.88 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2941,  Accuracy: 4300/4924 (87.33%)
#
#           True Positive: 27.66%
#           True Negative: 59.67%
#           False Positive: 5.32%
#           False Negative 7.33%
#
#
# Test set:  Avg. loss: 0.1836, Accuracy: 857/1232 (69.56%)
#
#           True Positive: 29.87%
#           True Negative: 39.69%
#           False Positive: 25.24%
#           False Negative 5.03%
#
# -----------Epoch 92 (time = 474.86 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2924,  Accuracy: 4320/4924 (87.73%)
#
#           True Positive: 27.76%
#           True Negative: 59.97%
#           False Positive: 5.02%
#           False Negative 7.23%
#
#
# Test set:  Avg. loss: 0.1628, Accuracy: 909/1232 (73.78%)
#
#           True Positive: 17.37%
#           True Negative: 56.41%
#           False Positive: 8.52%
#           False Negative 17.53%
#
# -----------Epoch 93 (time = 474.74 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2769,  Accuracy: 4339/4924 (88.12%)
#
#           True Positive: 27.99%
#           True Negative: 60.13%
#           False Positive: 4.85%
#           False Negative 7.01%
#
#
# Test set:  Avg. loss: 0.1370, Accuracy: 958/1232 (77.76%)
#
#           True Positive: 20.37%
#           True Negative: 57.39%
#           False Positive: 7.55%
#           False Negative 14.53%
#
# -----------Epoch 94 (time = 474.34 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2822,  Accuracy: 4365/4924 (88.65%)
#
#           True Positive: 28.53%
#           True Negative: 60.11%
#           False Positive: 4.87%
#           False Negative 6.46%
#
#
# Test set:  Avg. loss: 0.1878, Accuracy: 904/1232 (73.38%)
#
#           True Positive: 11.85%
#           True Negative: 61.53%
#           False Positive: 3.41%
#           False Negative 23.05%
#
# -----------Epoch 95 (time = 474.01 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.2754,  Accuracy: 4350/4924 (88.34%)
#
#           True Positive: 28.29%
#           True Negative: 60.05%
#           False Positive: 4.94%
#           False Negative 6.70%
#
#
# Test set:  Avg. loss: 0.1481, Accuracy: 944/1232 (76.62%)
#
#           True Positive: 19.72%
#           True Negative: 56.90%
#           False Positive: 8.04%
#           False Negative 15.18%
#
# -----------Epoch 96 (time = 474.52 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2670,  Accuracy: 4351/4924 (88.36%)
#
#           True Positive: 28.19%
#           True Negative: 60.17%
#           False Positive: 4.81%
#           False Negative 6.80%
#
#
# Test set:  Avg. loss: 0.1767, Accuracy: 914/1232 (74.19%)
#
#           True Positive: 22.97%
#           True Negative: 51.22%
#           False Positive: 13.72%
#           False Negative 11.93%
#
# -----------Epoch 97 (time = 474.23 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.2594,  Accuracy: 4370/4924 (88.75%)
#
#           True Positive: 28.74%
#           True Negative: 60.01%
#           False Positive: 4.98%
#           False Negative 6.26%
#
#
# Test set:  Avg. loss: 0.2557, Accuracy: 795/1232 (64.53%)
#
#           True Positive: 19.40%
#           True Negative: 45.13%
#           False Positive: 19.81%
#           False Negative 15.50%
#
# -----------Epoch 98 (time = 474.82 s  aka   7.91  mins) ----------------
# Train set: Avg. loss: 0.2543,  Accuracy: 4381/4924 (88.97%)
#
#           True Positive: 28.74%
#           True Negative: 60.24%
#           False Positive: 4.75%
#           False Negative 6.26%
#
#
# Test set:  Avg. loss: 0.2186, Accuracy: 884/1232 (71.75%)
#
#           True Positive: 16.31%
#           True Negative: 55.44%
#           False Positive: 9.50%
#           False Negative 18.59%
#
# -----------Epoch 99 (time = 475.15 s  aka   7.92  mins) ----------------
# Train set: Avg. loss: 0.2394,  Accuracy: 4437/4924 (90.11%)
#
#           True Positive: 29.14%
#           True Negative: 60.97%
#           False Positive: 4.02%
#           False Negative 5.85%
#
#
# Test set:  Avg. loss: 0.2004, Accuracy: 907/1232 (73.62%)
#
#           True Positive: 15.10%
#           True Negative: 58.52%
#           False Positive: 6.41%
#           False Negative 19.81%
#
# -----------Epoch 100 (time = 473.74 s  aka   7.9  mins) ----------------
# Train set: Avg. loss: 0.2297,  Accuracy: 4436/4924 (90.09%)
#
#           True Positive: 29.39%
#           True Negative: 60.70%
#           False Positive: 4.29%
#           False Negative 5.61%
#
#
# Test set:  Avg. loss: 0.1577, Accuracy: 981/1232 (79.63%)
#
#           True Positive: 22.65%
#           True Negative: 56.98%
#           False Positive: 7.95%
#           False Negative 12.26%
#
# Training complete (time = 47265.69 s)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Loss per Epoch")
plt.plot(train_losses, "-b",  label="train")
plt.plot(test_losses, "-r", label="test")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc="upper right")

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Accuracy per Epoch")
plt.plot(train_acc, "-b", label="train")
plt.plot(test_acc, "-r", label="test")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc="upper right")

# %%
# torch.save(network.state_dict(), 
#            os.path.join('/home/nick/workspace/saved_models/classifier_nodule.pth'))
